# %%
# import os
# from dotenv import load_dotenv

# load_dotenv()  # tenta carregar .env novamente (caso exista)

# print("OPENAI_API_KEY existe?", "OPENAI_API_KEY" in os.environ)
# print("Valor da chave (primeiros 7 + últimos 4 chars):")
# key = os.getenv("OPENAI_API_KEY")
# if key:
#     print(f"{key[:7]}...{key[-4:]}")
# else:
#     print("Nenhuma chave encontrada!")

# %%
from app.retrieval.retriever import retrieve, get_relevant_documents, get_relevant_documents

# %%
query_example = "What is the input parameters for createMOI in release 18"

# %%
# Test LangGraph compatibility (only docs)
docs = get_relevant_documents(query_example, k=5)
print(f"\nDocs returned for LangGraph: {len(docs)}")
print("First doc preview:", docs if docs else "No docs")

# %%
docs

# %%
# Test LangGraph compatibility (only docs)
docs = get_relevant_documents(query_example, k=5, filters={"release": "Rel-18"})
print(f"\nDocs returned for LangGraph: {len(docs)}")
print("First doc preview:", docs if docs else "No docs")

# %%
# Test SelfQuery mode
result = retrieve(query=query_example, k=5)

# Show the returned result
print("Generated semantic query:", result["generated_query"])
print("Generated filter:", result["generated_filter"])
print(f"\nFound {len(result['docs'])} documents:\n")

for i, doc in enumerate(result["docs"], 1):
    print(f"[{i}]")
    print(f"release: {doc.metadata.get('release')}")
    print(f"series: {doc.metadata.get('series')}")
    print(f"spec: {doc.metadata.get('spec')}")
    print(f"chunk_index: {doc.metadata.get('chunk_index')}")
    print(f"text preview:\n{doc.page_content}\n")
    print("-" * 80)
# Out:
# 2026-02-19 22:47:00 [INFO] rag_project: Starting retrieval for query: What is the input parameters for createMOI in release 18 | k=5 | filters=None
# 2026-02-19 22:47:00 [INFO] httpx: HTTP Request: GET http://localhost:6333 "HTTP/1.1 200 OK"
# 2026-02-19 22:47:02 [INFO] sentence_transformers.SentenceTransformer: Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2026-02-19 22:47:02 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:02 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/modules.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:02 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:02 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:03 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:03 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:03 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:03 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/README.md "HTTP/1.1 200 OK"
# 2026-02-19 22:47:03 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:03 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/modules.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:03 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/sentence_bert_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:03 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/sentence_bert_config.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:03 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-02-19 22:47:03 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-02-19 22:47:03 [WARNING] huggingface_hub.utils._http: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-02-19 22:47:03 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config.json "HTTP/1.1 200 OK"
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1980.27it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-02-19 22:47:04 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:04 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:04 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:04 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:04 [INFO] httpx: HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-02-19 22:47:04 [INFO] httpx: HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-02-19 22:47:04 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:04 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:05 [INFO] httpx: HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2 "HTTP/1.1 200 OK"
# 2026-02-19 22:47:05 [INFO] httpx: HTTP Request: GET http://localhost:6333/collections/3gpp_rel18_28 "HTTP/1.1 200 OK"
# 2026-02-19 22:47:05 [INFO] rag_project: Using SelfQueryRetriever (LLM parsing)
# 2026-02-19 22:47:05 [INFO] httpx: HTTP Request: GET http://localhost:6333 "HTTP/1.1 200 OK"
# 2026-02-19 22:47:05 [INFO] sentence_transformers.SentenceTransformer: Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2026-02-19 22:47:05 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:05 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/modules.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:05 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:05 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:06 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:06 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:06 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:06 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/README.md "HTTP/1.1 200 OK"
# 2026-02-19 22:47:06 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:06 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/modules.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:06 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/sentence_bert_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:06 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/sentence_bert_config.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:06 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-02-19 22:47:06 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:06 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config.json "HTTP/1.1 200 OK"
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1796.16it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-02-19 22:47:07 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:07 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:07 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:07 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:07 [INFO] httpx: HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-02-19 22:47:07 [INFO] httpx: HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-02-19 22:47:07 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-02-19 22:47:08 [INFO] httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# 2026-02-19 22:47:08 [INFO] httpx: HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2 "HTTP/1.1 200 OK"
# 2026-02-19 22:47:08 [INFO] httpx: HTTP Request: GET http://localhost:6333/collections/3gpp_rel18_28 "HTTP/1.1 200 OK"
# 2026-02-19 22:47:09 [INFO] httpx: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-19 22:47:10 [INFO] httpx: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-19 22:47:10 [INFO] langchain.retrievers.self_query.base: Generated Query: query='input parameters for createMOI' filter=Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='release', value='Rel-18') limit=None
# 2026-02-19 22:47:10 [INFO] httpx: HTTP Request: POST http://localhost:6333/collections/3gpp_rel18_28/points/query "HTTP/1.1 200 OK"
# 2026-02-19 22:47:10 [INFO] rag_project: Retrieval finished. Found 5 documents.
# 2026-02-19 22:47:10 [INFO] rag_project: Generated query: input parameters for createMOI
# 2026-02-19 22:47:10 [INFO] rag_project: Generated filter: comparator=<Comparator.EQ: 'eq'> attribute='release' value='Rel-18'
# Generated semantic query: input parameters for createMOI
# Generated filter: comparator=<Comparator.EQ: 'eq'> attribute='release' value='Rel-18'
#
# Found 5 documents:
#
# [1]
# release: Rel-18
# series: 28_series
# spec: 28532-i00
# chunk_index: 105
# text preview:
# that value will be used.
# ##### 11.1.1.1.2 Input parameters
# Parameter Name          S   Information Type / Legal Values                        Comment
#
# --------------------------------------------------------------------------------
# [2]
# release: Rel-18
# series: 28_series
# spec: 28532-i00
# chunk_index: 16
# text preview:
# 11.1.1.1 createMOI operation 19
# 11.1.1.1.1 Description 19
# 11.1.1.1.2 Input parameters 19
# 11.1.1.1.3 Output parameters 20
# 11.1.1.1.4 Results 20
# 11.1.1.2 getMOIAttributes operation 21
# 11.1.1.2.1 Definition 21
# 11.1.1.2.2 Input Parameters 21
# 11.1.1.2.3 Output Parameters 22
# 11.1.1.2.4 Results 23
# 11.1.1.3 modifyMOIAttributes operation 23
# 11.1.1.3.1 Description 23
# 11.1.1.3.2 Input parameters 24
# 11.1.1.3.3 Output parameters 26
# 11.1.1.3.4 Results 26
#
# --------------------------------------------------------------------------------
# [3]
# release: Rel-18
# series: 28_series
# spec: 28532-i00
# chunk_index: None
# text preview:
# 3\) If the attribute does not have a default value specified and is
# specified as incapable of carrying null value and incapable of carrying
# no information, if there is a MnS producer defined default value, then
# that value will be used.
# ##### 11.1.1.1.2 Input parameters
# Parameter Name          S   Information Type / Legal Values                        Comment
# ----------------------- --- ------------------------------------------------------ ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# managedObjectClass      M   class                                                  This parameter specifies the class of the new managed object instance.
#
# --------------------------------------------------------------------------------
# [4]
# release: Rel-18
# series: 28_series
# spec: 28532-i00
# chunk_index: None
# text preview:
# 3\) If the attribute does not have a default value specified and is
# specified as incapable of carrying null value and incapable of carrying
# no information, if there is a MnS producer defined default value, then
# that value will be used.
# ##### 11.1.1.1.2 Input parameters
# Parameter Name          S   Information Type / Legal Values                        Comment
# ----------------------- --- ------------------------------------------------------ ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# managedObjectClass      M   class                                                  This parameter specifies the class of the new managed object instance.
#
# --------------------------------------------------------------------------------
# [5]
# release: Rel-18
# series: 28_series
# spec: 28532-i00
# chunk_index: 46
# text preview:
# 3\) If the attribute does not have a default value specified and is
# specified as incapable of carrying null value and incapable of carrying
# no information, if there is a MnS producer defined default value, then
# that value will be used.
# ##### 11.1.1.1.2 Input parameters
# Parameter Name          S   Information Type / Legal Values                        Comment
# ----------------------- --- ------------------------------------------------------ ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# managedObjectClass      M   class                                                  This parameter specifies the class of the new managed object instance.
#
# --------------------------------------------------------------------------------

# %%
docs[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 docs[0]
#
# NameError: name 'docs' is not defined
